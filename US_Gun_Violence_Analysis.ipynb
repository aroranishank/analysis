# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/admin/Downloads/gun-violence-data_01-2013_03-2018.csv')
df.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# ...

# %%
df.corr()
# Out:
#                              incident_id  n_killed  n_injured  \
# incident_id                     1.000000  0.005052   0.009060
# n_killed                        0.005052  1.000000  -0.125425
# n_injured                       0.009060 -0.125425   1.000000
# incident_url_fields_missing          NaN       NaN        NaN
# congressional_district         -0.003585  0.055545  -0.007636
# latitude                        0.019365 -0.080078  -0.011379
# longitude                      -0.017031 -0.062149   0.036962
# n_guns_involved                -0.029638 -0.028200  -0.038843
# state_house_district           -0.002243 -0.006015  -0.030355
# state_senate_district          -0.007790 -0.010650  -0.044294
#
#                              incident_url_fields_missing  \
# incident_id                                          NaN
# n_killed                                             NaN
# n_injured                                            NaN
# ...

# %%
df.columns.tolist()
df.transpose()[0]
# Out:
# incident_id                                                               461105
# date                                                                  2013-01-01
# state                                                               Pennsylvania
# city_or_county                                                        Mckeesport
# address                                1506 Versailles Avenue and Coursin Street
# n_killed                                                                       0
# n_injured                                                                      4
# incident_url                   http://www.gunviolencearchive.org/incident/461105
# source_url                     http://www.post-gazette.com/local/south/2013/0...
# incident_url_fields_missing                                                False
# congressional_district                                                        14
# gun_stolen                                                                   NaN
# ...

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239677 entries, 0 to 239676
# Data columns (total 29 columns):
# incident_id                    239677 non-null int64
# date                           239677 non-null object
# state                          239677 non-null object
# city_or_county                 239677 non-null object
# address                        223180 non-null object
# n_killed                       239677 non-null int64
# n_injured                      239677 non-null int64
# incident_url                   239677 non-null object
# source_url                     239209 non-null object
# incident_url_fields_missing    239677 non-null bool
# congressional_district         227733 non-null float64
# gun_stolen                     140179 non-null object
# gun_type                       140226 non-null object
# incident_characteristics       239351 non-null object
# latitude                       231754 non-null float64
# ...

# %% [markdown]
# # Number of incidents by State

# %%
#For plotting
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
print('This dataset has ' + str(df.shape[0]) + ' rows, and ' + str(df.shape[1]) + ' columns')
# Out:
# This dataset has 239677 rows, and 29 columns

# %%
df
# Out:
#         incident_id        date                 state  \
# 0            461105  2013-01-01          Pennsylvania
# 1            460726  2013-01-01            California
# 2            478855  2013-01-01                  Ohio
# 3            478925  2013-01-05              Colorado
# 4            478959  2013-01-07        North Carolina
# 5            478948  2013-01-07              Oklahoma
# 6            479363  2013-01-19            New Mexico
# 7            479374  2013-01-21             Louisiana
# 8            479389  2013-01-21            California
# 9            492151  2013-01-23              Maryland
# 10           491674  2013-01-23             Tennessee
# 11           479413  2013-01-25              Missouri
# 12           479561  2013-01-26             Louisiana
# 13           479554  2013-01-26  District of Columbia
# 14           479460  2013-01-26                  Ohio
# 15           479573  2013-02-02             Tennessee
# ...

# %%
df['count'] = df.groupby('state')['state'].count()
df['count']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
#           ..
# 239647   NaN
# 239648   NaN
# 239649   NaN
# 239650   NaN
# 239651   NaN
# 239652   NaN
# 239653   NaN
# 239654   NaN
# 239655   NaN
# 239656   NaN
# 239657   NaN
# 239658   NaN
# 239659   NaN
# 239660   NaN
# 239661   NaN
# 239662   NaN
# 239663   NaN
# 239664   NaN
# 239665   NaN
# 239666   NaN
# 239667   NaN
# 239668   NaN
# 239669   NaN
# 239670   NaN
# 239671   NaN
# 239672   NaN
# 239673   NaN
# 239674   NaN
# 239675   NaN
# 239676   NaN
# Name: count, Length: 239677, dtype: float64

# %%
statewise_numbers = df.groupby('state')['state'].count()

# %%
statewise_numbers.head()
statewise_numbers.columns = ['states', 'count']

# %%
statewise_numbers.rename(columns={'state': 'State', '': 'Number_of_incidents'}, inplace=True)
# Out:
# state
# Alabama                  5471
# Alaska                   1349
# Arizona                  2328
# Arkansas                 2842
# California              16306
# Colorado                 3201
# Connecticut              3067
# Delaware                 1685
# District of Columbia     3195
# Florida                 15029
# Georgia                  8925
# Hawaii                    289
# Idaho                     661
# Illinois                17556
# Indiana                  5852
# Iowa                     2517
# Kansas                   2145
# Kentucky                 4157
# Louisiana                8103
# Maine                     907
# Maryland                 5798
# Massachusetts            5981
# Michigan                 6136
# Minnesota                2408
# Mississippi              3599
# Missouri                 6631
# Montana                   638
# Nebraska                 1651
# Nevada                   1952
# New Hampshire             964
# New Jersey               5387
# ...

# %%
df_new = pd.DataFrame({'state':statewise_numbers.index, 'Number_of_incidents':statewise_numbers.values})

# %%
df_new
# Out:
#                    state  Number_of_incidents
# 0                Alabama                 5471
# 1                 Alaska                 1349
# 2                Arizona                 2328
# 3               Arkansas                 2842
# 4             California                16306
# 5               Colorado                 3201
# 6            Connecticut                 3067
# 7               Delaware                 1685
# 8   District of Columbia                 3195
# 9                Florida                15029
# 10               Georgia                 8925
# 11                Hawaii                  289
# 12                 Idaho                  661
# 13              Illinois                17556
# 14               Indiana                 5852
# 15                  Iowa                 2517
# 16                Kansas                 2145
# 17              Kentucky                 4157
# 18             Louisiana                 8103
# ...

# %%
import pandas as pd
df_states = pd.read_csv('/Users/admin/my-documents/fips_state.csv')
df_states
# Out:
#     fips_code post_code                                         state
# 0           1        AL                                       Alabama
# 1           2        AK                                        Alaska
# 2           4        AZ                                       Arizona
# 3           5        AR                                      Arkansas
# 4           6        CA                                    California
# 5           8        CO                                      Colorado
# 6           9        CT                                   Connecticut
# 7          10        DE                                      Delaware
# 8          11        DC                          District of Columbia
# 9          12        FL                                       Florida
# 10         13        GA                                       Georgia
# 11         15        HI                                        Hawaii
# ...

# %%
tls.set_credentials_file(username='nishank91', api_key='7FSzXkk3EYSLYU8NSHuC')

# %%
df1
# Out:
#    code           state category total exports   beef    pork poultry   dairy  \
# 0    AL         Alabama    state       1390.63   34.4    10.6   481.0    4.06
# 1    AK          Alaska    state         13.31    0.2     0.1     0.0    0.19
# 2    AZ         Arizona    state       1463.17   71.3    17.9     0.0  105.48
# 3    AR        Arkansas    state       3586.02   53.2    29.4   562.9    3.53
# 4    CA      California    state      16472.88  228.7    11.1   225.4  929.95
# 5    CO        Colorado    state       1851.33  261.4    66.0    14.0   71.94
# 6    CT     Connecticut    state        259.62    1.1     0.1     6.9    9.49
# 7    DE        Delaware    state        282.19    0.4     0.6   114.7     2.3
# 8    FL         Florida    state       3764.09   42.6     0.9    56.9   66.31
# 9    GA         Georgia    state       2860.84   31.0    18.9   630.4   38.38
# 10   HI          Hawaii    state        401.84    4.0     0.7     1.3    1.16
# ...

# %%
df_new.rename(columns={'post_code':'state'},inplace=True)
df_new
# Out:
#                    state  Number_of_incidents
# 0                Alabama                 5471
# 1                 Alaska                 1349
# 2                Arizona                 2328
# 3               Arkansas                 2842
# 4             California                16306
# 5               Colorado                 3201
# 6            Connecticut                 3067
# 7               Delaware                 1685
# 8   District of Columbia                 3195
# 9                Florida                15029
# 10               Georgia                 8925
# 11                Hawaii                  289
# 12                 Idaho                  661
# 13              Illinois                17556
# 14               Indiana                 5852
# 15                  Iowa                 2517
# 16                Kansas                 2145
# 17              Kentucky                 4157
# 18             Louisiana                 8103
# ...

# %%
result = pd.merge(df_new,df_states,on='state',how='inner')
result
# Out:
#                    state  Number_of_incidents  fips_code post_code
# 0                Alabama                 5471          1        AL
# 1                 Alaska                 1349          2        AK
# 2                Arizona                 2328          4        AZ
# 3               Arkansas                 2842          5        AR
# 4             California                16306          6        CA
# 5               Colorado                 3201          8        CO
# 6            Connecticut                 3067          9        CT
# 7               Delaware                 1685         10        DE
# 8   District of Columbia                 3195         11        DC
# 9                Florida                15029         12        FL
# 10               Georgia                 8925         13        GA
# 11                Hawaii                  289         15        HI
# 12                 Idaho                  661         16        ID
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.tools as tls

import pandas as pd

#df1 = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')

#for col in df1.columns:
#    df1[col] = df1[col].astype(str)

scl = [
    [0.0, 'rgb(240,230,255)'],
    [0.1, 'rgb(224,204,255)'],
    [0.2, 'rgb(209,179,255)'],
    [0.3, 'rgb(194,153,255)'],
    [0.4, 'rgb(179,128,255)'],
    [0.5, 'rgb(163,102,255)'],
    [0.6, 'rgb(148,77,255)'],
    [0.7, 'rgb(133,51,255)'],
    [0.8, 'rgb(117,26,255)'],
    [0.9, 'rgb(102,0,255)'],
    [1.0, 'rgb(92,0,230)']
]

# %%
result['text'] = result['state']
data = [go.Choropleth(
    colorscale = scl,
    autocolorscale = False,
    locations = result['post_code'],
    z = result['Number_of_incidents'].astype(float),
    locationmode = 'USA-states',
    text = result['text'],
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(255,255,255)',
            width = 2,
        )),
    colorbar = go.choropleth.ColorBar(
        title = "Number of incidents")
)]

# %%
layout = go.Layout(
    title = go.layout.Title(
        text = 'Gun Violence by State<br>(Hover for breakdown)'
    ),
    geo = go.layout.Geo(
        scope = 'usa',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255, 255, 255)'),
)

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = 'd3-cloropleth-map')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~nishank91/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nishank91/0.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Number of incidents on the basis of population per state

# %%
df.groupby('Num')

# %% [markdown]
# # Age Group by State

# %%
df
# Out:
#         incident_id        date                 state  \
# 0            461105  2013-01-01          Pennsylvania
# 1            460726  2013-01-01            California
# 2            478855  2013-01-01                  Ohio
# 3            478925  2013-01-05              Colorado
# 4            478959  2013-01-07        North Carolina
# 5            478948  2013-01-07              Oklahoma
# 6            479363  2013-01-19            New Mexico
# 7            479374  2013-01-21             Louisiana
# 8            479389  2013-01-21            California
# 9            492151  2013-01-23              Maryland
# 10           491674  2013-01-23             Tennessee
# 11           479413  2013-01-25              Missouri
# 12           479561  2013-01-26             Louisiana
# 13           479554  2013-01-26  District of Columbia
# 14           479460  2013-01-26                  Ohio
# 15           479573  2013-02-02             Tennessee
# ...

# %% [markdown]
# # Yearwise incidents

# %% [markdown]
# # Number of injured to number of incidents with every state
